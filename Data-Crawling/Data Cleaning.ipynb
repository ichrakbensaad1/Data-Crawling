# %%
import pandas as pd

data= pd.read_csv('SearchResults (1).csv', error_bad_lines=False)
data.info()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Rank                     1000 non-null   int64
#  1   NCT Number               1000 non-null   object
#  2   Title                    1000 non-null   object
#  3   Acronym                  260 non-null    object
#  4   Status                   1000 non-null   object
#  5   Study Results            1000 non-null   object
#  6   Conditions               998 non-null    object
#  7   Interventions            921 non-null    object
#  8   Outcome Measures         996 non-null    object
#  9   Sponsor/Collaborators    1000 non-null   object
#  10  Gender                   998 non-null    object
#  11  Age                      998 non-null    object
#  12  Phases                   761 non-null    object
#  13  Enrollment               996 non-null    float64
# ...

# %%
#Supprimer les colonnes vides : Results First Posted & Study Documents
data.drop(['Results First Posted', 'Study Documents'],axis=1, inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Rank                     1000 non-null   int64
#  1   NCT Number               1000 non-null   object
#  2   Title                    1000 non-null   object
#  3   Acronym                  260 non-null    object
#  4   Status                   1000 non-null   object
#  5   Study Results            1000 non-null   object
#  6   Conditions               998 non-null    object
#  7   Interventions            921 non-null    object
#  8   Outcome Measures         996 non-null    object
#  9   Sponsor/Collaborators    1000 non-null   object
#  10  Gender                   998 non-null    object
#  11  Age                      998 non-null    object
#  12  Phases                   761 non-null    object
#  13  Enrollment               996 non-null    float64
# ...

# %%
#Data cleaning for float/int Data

#"max" function
def replace_max(x):
    data[x]=data[x].fillna(data[x].max())        
    data.info()

# %%
replace_max("Enrollment")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Rank                     1000 non-null   int64
#  1   NCT Number               1000 non-null   object
#  2   Title                    1000 non-null   object
#  3   Acronym                  260 non-null    object
#  4   Status                   1000 non-null   object
#  5   Study Results            1000 non-null   object
#  6   Conditions               998 non-null    object
#  7   Interventions            921 non-null    object
#  8   Outcome Measures         996 non-null    object
#  9   Sponsor/Collaborators    1000 non-null   object
#  10  Gender                   998 non-null    object
#  11  Age                      998 non-null    object
#  12  Phases                   761 non-null    object
#  13  Enrollment               1000 non-null   float64
# ...

# %%
def replace_min(x):
    data[x]=data[x].fillna(data[x].min())        
    data.info()

# %%
def replace_max(x):
    data[x]=data[x].fillna(data[x].max())        
    data.info()

# %%
def replace_mean(x):
    data[x]=data[x].fillna(data[x].mean())        
    data.info()

# %%
def replace_constat(x):
    data[x]=data[x].fillna(value='x')
    data.info()

# %%
def drop(x):
    data[x]=data[x].fillna(data[x].dropna)

# %%
def
